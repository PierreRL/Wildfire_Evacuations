# %%
import pandas as pd

# %%
nfdb = pd.read_csv("../data/NFDB_point.csv")
evac = pd.read_csv("../data/Canadian_Wildfire_Evacuation_Data.csv")

# %%
len(nfdb)
# Out:
# 15206

# %%
len(evac)
# Out:
# 1043

# %%
evac['FireSource'].head(2)
# Out:
# 0    NFDB.poly
# 1    NFDB.poly
# Name: FireSource, dtype: str

# %%
evac.columns
# Out:
# Index(['EvacID', 'Year', 'Province', 'Location', 'Lat', 'Long', 'Population',
#        'PopulationNotes', 'FN_Reserve', 'EvacSize', 'IssueDate', 'EndDate',
#        'EvacReason', 'Region', 'Group', 'FireSource', 'RepDOY', 'FireIgnit',
#        'FireSize'],
#       dtype='str')

# %%
evac.head(2)
# Out:
#    EvacID  Year Province    Location        Lat        Long Population  \
# 0       1  1980       MB  Clear Lake  50.678605  -99.911954        NaN
# 1       2  1980       MB    Mafeking  52.683611 -101.110000        500
#
#         PopulationNotes FN_Reserve               EvacSize  IssueDate  \
# 0                   NaN         no  Very Small (1 to 100)  5/23/1980
# 1  estimate (newspaper)         no   Small (101 to 1,000)  5/22/1980
#
#      EndDate EvacReason Region Group FireSource  RepDOY  FireIgnit  \
# 0  5/27/1980     Threat     SC   SC3  NFDB.poly   142.0      Human
# 1  5/28/1980     Threat     SC   SC2  NFDB.poly   139.0  Lightning
#
#       FireSize
# 0  22914.74086
# 1  79934.29348

# %%
nfdb.head(2)
# Out:
#             FID                                       the_geom  \
# 0  NFDB_point.1  POINT (-1750186.0665132757 377790.0166569017)
# 1  NFDB_point.2  POINT (-1851062.9070163155 752606.0430763443)
#
#             NFDBFIREID SRC_AGENCY NAT_PARK      FIRE_ID              FIRENAME  \
# 0  BC-2023-2023-K52813         BC      NaN  2023-K52813  UPPER PARK RILL C...
# 1  BC-2023-2023-C50100         BC      NaN  2023-C50100        DRIPPING WATER
#
#    LATITUDE  LONGITUDE  YEAR  MONTH  DAY             REP_DATE  \
# 0   49.3014  -119.7091  2023      8   18  2023-08-18T00:00:00
# 1   52.0351  -123.1770  2023      4   27  2023-04-27T00:00:00
#
#               OUT_DATE  SIZE_HA CAUSE FIRE_TYPE RESPONSE PROTZONE  \
# 0  2023-10-26T00:00:00   2043.8     H      Fire      FUL      NaN
# 1  2023-05-29T00:00:00    209.0     H      Fire      FUL      NaN
#
#                   MORE_INFO
# 0     Upper Park Rill Creek
# 1  E of Dripping Water Road

# %%
nfdb[(nfdb['SIZE_HA'] > 22914) & (nfdb['SIZE_HA'] < 22915)]
# Out:
# Empty DataFrame
# Columns: [FID, the_geom, NFDBFIREID, SRC_AGENCY, NAT_PARK, FIRE_ID, FIRENAME, LATITUDE, LONGITUDE, YEAR, MONTH, DAY, REP_DATE, OUT_DATE, SIZE_HA, CAUSE, FIRE_TYPE, RESPONSE, PROTZONE, MORE_INFO]
# Index: []
